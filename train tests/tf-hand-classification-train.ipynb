# %%
import glob
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from tensorflow.keras.applications import MobileNet, MobileNetV2, VGG19, EfficientNetB0
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from scipy.optimize import minimize
import tensorflow as tf
# Out:
# 2025-05-21 09:10:21.672381: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747818621.849575      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747818621.900311      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Load all image paths
all_paths = glob.glob('/kaggle/input/hg14-handgesture14-dataset/HG14/HG14-Hand Gesture/*/*.jpg')

# Prepare dataset
data, labels = [], []
for path in tqdm(all_paths):
    img = cv2.imread(path)
    img = cv2.resize(img, (128, 128))
    label = path.split('/')[-2]
    data.append(img)
    labels.append(label)

data = np.array(data) / 255.0
labels = pd.factorize(labels)[0]

# Split data
X_temp, X_test, y_temp, y_test = train_test_split(data, labels, test_size=0.10, stratify=labels, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.20, stratify=y_temp, random_state=42)

# Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
# Out:
# 100%|██████████| 14000/14000 [02:02<00:00, 114.39it/s]
# /tmp/ipykernel_35/213992276.py:14: FutureWarning: factorize with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   labels = pd.factorize(labels)[0]

# %%
# Model Builder
def build_model(base_model_fn, input_shape=(128, 128, 3), num_classes=14):
    base_model = base_model_fn(include_top=False, input_shape=input_shape, weights='imagenet')
    for layer in base_model.layers:
        layer.trainable = False  # Freeze base layers initially

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=x)
    model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# Settings
batch_size = 20
epochs = 50

callbacks = [
    EarlyStopping(patience=5, restore_best_weights=True),
    ReduceLROnPlateau(patience=3)
]

models_dict = {
    'MobileNetV2': MobileNetV2,
    'VGG19': VGG19
}

trained_models = {}
val_preds = {}
test_preds = {}

# %%
from keras.callbacks import ModelCheckpoint

trained_models = {}
val_preds = {}
test_preds = {}

for name, model_fn in models_dict.items():
    print(f"\nTraining {name}")
    
    model = build_model(model_fn)

    # Create a checkpoint callback specific to this model
    checkpoint_cb = ModelCheckpoint(
        filepath=f"/kaggle/working/{name}_best.h5",
        save_best_only=True,
        monitor="val_accuracy",   # or "val_loss"
        mode="max",               # "min" if using val_loss
        verbose=1
    )

    model.fit(
        datagen.flow(X_train, y_train, batch_size=batch_size),
        epochs=epochs,
        validation_data=(X_val, y_val),
        callbacks=[checkpoint_cb],  # using model-specific callback
        verbose=1
    )

    val_preds[name] = model.predict(X_val)
    test_preds[name] = model.predict(X_test)
    trained_models[name] = model
# Out:
# Training MobileNetV2
# I0000 00:00:1747819456.905621      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1747819456.906235      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747819470.222936     100 service.cc:148] XLA service 0x7e7d14003790 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747819470.223889     100 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1747819470.223909     100 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1747819471.164195     100 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   4/504 ━━━━━━━━━━━━━━━━━━━━ 27s 54ms/step - accuracy: 0.1188 - loss: 3.7131
# I0000 00:00:1747819475.643032     100 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6166 - loss: 1.2264
# Epoch 1: val_accuracy improved from -inf to 0.90476, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 57s 86ms/step - accuracy: 0.6168 - loss: 1.2255 - val_accuracy: 0.9048 - val_loss: 0.2632
# Epoch 2/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8232 - loss: 0.4960
# Epoch 2: val_accuracy improved from 0.90476 to 0.91905, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.8232 - loss: 0.4959 - val_accuracy: 0.9190 - val_loss: 0.2329
# Epoch 3/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8653 - loss: 0.3754
# Epoch 3: val_accuracy improved from 0.91905 to 0.92937, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.8653 - loss: 0.3754 - val_accuracy: 0.9294 - val_loss: 0.1936
# Epoch 4/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8674 - loss: 0.3684
# Epoch 4: val_accuracy improved from 0.92937 to 0.93770, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 68ms/step - accuracy: 0.8674 - loss: 0.3684 - val_accuracy: 0.9377 - val_loss: 0.1717
# Epoch 5/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8767 - loss: 0.3481
# Epoch 5: val_accuracy improved from 0.93770 to 0.94921, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.8767 - loss: 0.3481 - val_accuracy: 0.9492 - val_loss: 0.1480
# Epoch 6/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8803 - loss: 0.3357
# Epoch 6: val_accuracy improved from 0.94921 to 0.95159, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.8803 - loss: 0.3357 - val_accuracy: 0.9516 - val_loss: 0.1420
# Epoch 7/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8901 - loss: 0.3167
# Epoch 7: val_accuracy improved from 0.95159 to 0.95397, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.8901 - loss: 0.3167 - val_accuracy: 0.9540 - val_loss: 0.1371
# Epoch 8/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8917 - loss: 0.2883
# Epoch 8: val_accuracy did not improve from 0.95397
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 68ms/step - accuracy: 0.8916 - loss: 0.2883 - val_accuracy: 0.9496 - val_loss: 0.1408
# Epoch 9/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8864 - loss: 0.3040
# Epoch 9: val_accuracy did not improve from 0.95397
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.8864 - loss: 0.3040 - val_accuracy: 0.9516 - val_loss: 0.1394
# Epoch 10/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8973 - loss: 0.2880
# Epoch 10: val_accuracy did not improve from 0.95397
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.8973 - loss: 0.2880 - val_accuracy: 0.9504 - val_loss: 0.1367
# Epoch 11/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9056 - loss: 0.2747
# Epoch 11: val_accuracy did not improve from 0.95397
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9056 - loss: 0.2748 - val_accuracy: 0.9528 - val_loss: 0.1353
# Epoch 12/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8912 - loss: 0.2971
# Epoch 12: val_accuracy improved from 0.95397 to 0.95595, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.8912 - loss: 0.2971 - val_accuracy: 0.9560 - val_loss: 0.1286
# Epoch 13/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9068 - loss: 0.2636
# Epoch 13: val_accuracy improved from 0.95595 to 0.95794, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9068 - loss: 0.2637 - val_accuracy: 0.9579 - val_loss: 0.1283
# Epoch 14/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9057 - loss: 0.2592
# Epoch 14: val_accuracy improved from 0.95794 to 0.96310, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9057 - loss: 0.2592 - val_accuracy: 0.9631 - val_loss: 0.1182
# Epoch 15/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9070 - loss: 0.2648
# Epoch 15: val_accuracy did not improve from 0.96310
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9070 - loss: 0.2648 - val_accuracy: 0.9607 - val_loss: 0.1162
# Epoch 16/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9014 - loss: 0.2700
# Epoch 16: val_accuracy improved from 0.96310 to 0.96349, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9014 - loss: 0.2699 - val_accuracy: 0.9635 - val_loss: 0.1133
# Epoch 17/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9075 - loss: 0.2627
# Epoch 17: val_accuracy did not improve from 0.96349
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 67ms/step - accuracy: 0.9075 - loss: 0.2627 - val_accuracy: 0.9556 - val_loss: 0.1295
# Epoch 18/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9115 - loss: 0.2396
# Epoch 18: val_accuracy did not improve from 0.96349
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 67ms/step - accuracy: 0.9114 - loss: 0.2396 - val_accuracy: 0.9623 - val_loss: 0.1085
# Epoch 19/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9169 - loss: 0.2356
# Epoch 19: val_accuracy did not improve from 0.96349
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9169 - loss: 0.2356 - val_accuracy: 0.9607 - val_loss: 0.1086
# Epoch 20/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9115 - loss: 0.2449
# Epoch 20: val_accuracy did not improve from 0.96349
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9115 - loss: 0.2449 - val_accuracy: 0.9627 - val_loss: 0.0988
# Epoch 21/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9180 - loss: 0.2238
# Epoch 21: val_accuracy improved from 0.96349 to 0.96548, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 68ms/step - accuracy: 0.9180 - loss: 0.2238 - val_accuracy: 0.9655 - val_loss: 0.0979
# Epoch 22/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9175 - loss: 0.2280
# Epoch 22: val_accuracy improved from 0.96548 to 0.96627, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9175 - loss: 0.2280 - val_accuracy: 0.9663 - val_loss: 0.0971
# Epoch 23/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9217 - loss: 0.2251
# Epoch 23: val_accuracy did not improve from 0.96627
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9217 - loss: 0.2250 - val_accuracy: 0.9651 - val_loss: 0.0941
# Epoch 24/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9194 - loss: 0.2248
# Epoch 24: val_accuracy improved from 0.96627 to 0.96786, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9194 - loss: 0.2248 - val_accuracy: 0.9679 - val_loss: 0.0906
# Epoch 25/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9272 - loss: 0.2093
# Epoch 25: val_accuracy improved from 0.96786 to 0.96825, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9272 - loss: 0.2093 - val_accuracy: 0.9683 - val_loss: 0.0930
# Epoch 26/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9158 - loss: 0.2417
# Epoch 26: val_accuracy did not improve from 0.96825
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9158 - loss: 0.2417 - val_accuracy: 0.9663 - val_loss: 0.0996
# Epoch 27/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9200 - loss: 0.2238
# Epoch 27: val_accuracy improved from 0.96825 to 0.97063, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9200 - loss: 0.2238 - val_accuracy: 0.9706 - val_loss: 0.0836
# Epoch 28/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9255 - loss: 0.2078
# Epoch 28: val_accuracy did not improve from 0.97063
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9255 - loss: 0.2078 - val_accuracy: 0.9690 - val_loss: 0.0870
# Epoch 29/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9177 - loss: 0.2297
# Epoch 29: val_accuracy did not improve from 0.97063
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9177 - loss: 0.2297 - val_accuracy: 0.9687 - val_loss: 0.0992
# Epoch 30/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9258 - loss: 0.2127
# Epoch 30: val_accuracy did not improve from 0.97063
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9258 - loss: 0.2127 - val_accuracy: 0.9683 - val_loss: 0.0910
# Epoch 31/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9250 - loss: 0.2094
# Epoch 31: val_accuracy did not improve from 0.97063
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9250 - loss: 0.2094 - val_accuracy: 0.9687 - val_loss: 0.0951
# Epoch 32/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9231 - loss: 0.2140
# Epoch 32: val_accuracy did not improve from 0.97063
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9231 - loss: 0.2140 - val_accuracy: 0.9643 - val_loss: 0.0969
# Epoch 33/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9212 - loss: 0.2219
# Epoch 33: val_accuracy improved from 0.97063 to 0.97183, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9212 - loss: 0.2219 - val_accuracy: 0.9718 - val_loss: 0.0870
# Epoch 34/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9301 - loss: 0.1966
# Epoch 34: val_accuracy did not improve from 0.97183
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9301 - loss: 0.1966 - val_accuracy: 0.9655 - val_loss: 0.0974
# Epoch 35/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9328 - loss: 0.1912
# Epoch 35: val_accuracy did not improve from 0.97183
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 68ms/step - accuracy: 0.9328 - loss: 0.1912 - val_accuracy: 0.9710 - val_loss: 0.0884
# Epoch 36/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9286 - loss: 0.1931
# Epoch 36: val_accuracy did not improve from 0.97183
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 68ms/step - accuracy: 0.9286 - loss: 0.1931 - val_accuracy: 0.9706 - val_loss: 0.0850
# Epoch 37/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9265 - loss: 0.2040
# Epoch 37: val_accuracy did not improve from 0.97183
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9265 - loss: 0.2040 - val_accuracy: 0.9687 - val_loss: 0.0905
# Epoch 38/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9328 - loss: 0.1942
# Epoch 38: val_accuracy did not improve from 0.97183
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9328 - loss: 0.1942 - val_accuracy: 0.9694 - val_loss: 0.0887
# Epoch 39/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9310 - loss: 0.1891
# Epoch 39: val_accuracy did not improve from 0.97183
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9310 - loss: 0.1891 - val_accuracy: 0.9706 - val_loss: 0.0826
# Epoch 40/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9305 - loss: 0.1983
# Epoch 40: val_accuracy improved from 0.97183 to 0.97659, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 68ms/step - accuracy: 0.9305 - loss: 0.1983 - val_accuracy: 0.9766 - val_loss: 0.0749
# Epoch 41/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9304 - loss: 0.2011
# Epoch 41: val_accuracy did not improve from 0.97659
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 67ms/step - accuracy: 0.9304 - loss: 0.2011 - val_accuracy: 0.9750 - val_loss: 0.0789
# Epoch 42/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9362 - loss: 0.1841
# Epoch 42: val_accuracy did not improve from 0.97659
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9362 - loss: 0.1841 - val_accuracy: 0.9742 - val_loss: 0.0830
# Epoch 43/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9310 - loss: 0.1922
# Epoch 43: val_accuracy did not improve from 0.97659
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9310 - loss: 0.1922 - val_accuracy: 0.9714 - val_loss: 0.0875
# Epoch 44/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9314 - loss: 0.1835
# Epoch 44: val_accuracy did not improve from 0.97659
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9314 - loss: 0.1835 - val_accuracy: 0.9734 - val_loss: 0.0807
# Epoch 45/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9387 - loss: 0.1720
# Epoch 45: val_accuracy did not improve from 0.97659
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9387 - loss: 0.1720 - val_accuracy: 0.9746 - val_loss: 0.0871
# Epoch 46/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9349 - loss: 0.1846
# Epoch 46: val_accuracy improved from 0.97659 to 0.97738, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - accuracy: 0.9349 - loss: 0.1846 - val_accuracy: 0.9774 - val_loss: 0.0762
# Epoch 47/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9345 - loss: 0.1825
# Epoch 47: val_accuracy did not improve from 0.97738
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9345 - loss: 0.1825 - val_accuracy: 0.9754 - val_loss: 0.0733
# Epoch 48/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9352 - loss: 0.1814
# Epoch 48: val_accuracy did not improve from 0.97738
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 35s 68ms/step - accuracy: 0.9352 - loss: 0.1814 - val_accuracy: 0.9730 - val_loss: 0.0779
# Epoch 49/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9375 - loss: 0.1786
# Epoch 49: val_accuracy did not improve from 0.97738
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9375 - loss: 0.1786 - val_accuracy: 0.9754 - val_loss: 0.0768
# Epoch 50/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9351 - loss: 0.1840
# Epoch 50: val_accuracy improved from 0.97738 to 0.97897, saving model to /kaggle/working/MobileNetV2_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 34s 68ms/step - accuracy: 0.9351 - loss: 0.1840 - val_accuracy: 0.9790 - val_loss: 0.0724
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
#
# Training VGG19
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Epoch 1/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4450 - loss: 1.7456
# Epoch 1: val_accuracy improved from -inf to 0.81905, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 66s 113ms/step - accuracy: 0.4452 - loss: 1.7448 - val_accuracy: 0.8190 - val_loss: 0.6144
# Epoch 2/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6926 - loss: 0.8830
# Epoch 2: val_accuracy improved from 0.81905 to 0.85675, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 42s 82ms/step - accuracy: 0.6926 - loss: 0.8829 - val_accuracy: 0.8567 - val_loss: 0.4345
# Epoch 3/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7274 - loss: 0.7757
# Epoch 3: val_accuracy improved from 0.85675 to 0.88611, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.7274 - loss: 0.7757 - val_accuracy: 0.8861 - val_loss: 0.3651
# Epoch 4/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7345 - loss: 0.7436
# Epoch 4: val_accuracy improved from 0.88611 to 0.89762, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.7345 - loss: 0.7435 - val_accuracy: 0.8976 - val_loss: 0.3358
# Epoch 5/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7600 - loss: 0.6927
# Epoch 5: val_accuracy did not improve from 0.89762
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.7600 - loss: 0.6927 - val_accuracy: 0.8845 - val_loss: 0.3533
# Epoch 6/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7605 - loss: 0.6837
# Epoch 6: val_accuracy did not improve from 0.89762
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.7605 - loss: 0.6837 - val_accuracy: 0.8976 - val_loss: 0.3094
# Epoch 7/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7722 - loss: 0.6576
# Epoch 7: val_accuracy improved from 0.89762 to 0.90278, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 42s 83ms/step - accuracy: 0.7722 - loss: 0.6576 - val_accuracy: 0.9028 - val_loss: 0.3054
# Epoch 8/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7789 - loss: 0.6324
# Epoch 8: val_accuracy improved from 0.90278 to 0.91151, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 42s 83ms/step - accuracy: 0.7789 - loss: 0.6324 - val_accuracy: 0.9115 - val_loss: 0.2821
# Epoch 9/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7738 - loss: 0.6500
# Epoch 9: val_accuracy improved from 0.91151 to 0.91468, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.7738 - loss: 0.6500 - val_accuracy: 0.9147 - val_loss: 0.2917
# Epoch 10/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7792 - loss: 0.6124
# Epoch 10: val_accuracy improved from 0.91468 to 0.92302, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.7792 - loss: 0.6125 - val_accuracy: 0.9230 - val_loss: 0.2692
# Epoch 11/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7877 - loss: 0.6076
# Epoch 11: val_accuracy did not improve from 0.92302
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.7877 - loss: 0.6076 - val_accuracy: 0.9060 - val_loss: 0.2793
# Epoch 12/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7948 - loss: 0.5796
# Epoch 12: val_accuracy improved from 0.92302 to 0.92778, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.7948 - loss: 0.5796 - val_accuracy: 0.9278 - val_loss: 0.2471
# Epoch 13/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7802 - loss: 0.6075
# Epoch 13: val_accuracy did not improve from 0.92778
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.7803 - loss: 0.6075 - val_accuracy: 0.9234 - val_loss: 0.2510
# Epoch 14/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7844 - loss: 0.5988
# Epoch 14: val_accuracy did not improve from 0.92778
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.7844 - loss: 0.5988 - val_accuracy: 0.9266 - val_loss: 0.2434
# Epoch 15/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7961 - loss: 0.5652
# Epoch 15: val_accuracy did not improve from 0.92778
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.7961 - loss: 0.5652 - val_accuracy: 0.9218 - val_loss: 0.2449
# Epoch 16/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8011 - loss: 0.5489
# Epoch 16: val_accuracy did not improve from 0.92778
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.8011 - loss: 0.5490 - val_accuracy: 0.9230 - val_loss: 0.2461
# Epoch 17/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7945 - loss: 0.5692
# Epoch 17: val_accuracy improved from 0.92778 to 0.93214, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 42s 82ms/step - accuracy: 0.7945 - loss: 0.5692 - val_accuracy: 0.9321 - val_loss: 0.2254
# Epoch 18/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8091 - loss: 0.5387
# Epoch 18: val_accuracy did not improve from 0.93214
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.8091 - loss: 0.5388 - val_accuracy: 0.9262 - val_loss: 0.2376
# Epoch 19/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7982 - loss: 0.5784
# Epoch 19: val_accuracy improved from 0.93214 to 0.93929, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 42s 83ms/step - accuracy: 0.7982 - loss: 0.5784 - val_accuracy: 0.9393 - val_loss: 0.2156
# Epoch 20/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8145 - loss: 0.5224
# Epoch 20: val_accuracy did not improve from 0.93929
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.8145 - loss: 0.5224 - val_accuracy: 0.9345 - val_loss: 0.2162
# Epoch 21/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7969 - loss: 0.5622
# Epoch 21: val_accuracy improved from 0.93929 to 0.94008, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.7969 - loss: 0.5622 - val_accuracy: 0.9401 - val_loss: 0.2173
# Epoch 22/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8011 - loss: 0.5414
# Epoch 22: val_accuracy did not improve from 0.94008
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 42s 83ms/step - accuracy: 0.8011 - loss: 0.5414 - val_accuracy: 0.9357 - val_loss: 0.2146
# Epoch 23/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8224 - loss: 0.5130
# Epoch 23: val_accuracy improved from 0.94008 to 0.94444, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 42s 82ms/step - accuracy: 0.8224 - loss: 0.5130 - val_accuracy: 0.9444 - val_loss: 0.2049
# Epoch 24/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8138 - loss: 0.5333
# Epoch 24: val_accuracy did not improve from 0.94444
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.8138 - loss: 0.5333 - val_accuracy: 0.9373 - val_loss: 0.2182
# Epoch 25/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8196 - loss: 0.5140
# Epoch 25: val_accuracy did not improve from 0.94444
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.8196 - loss: 0.5140 - val_accuracy: 0.9361 - val_loss: 0.2055
# Epoch 26/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8166 - loss: 0.5143
# Epoch 26: val_accuracy did not improve from 0.94444
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.8166 - loss: 0.5143 - val_accuracy: 0.9353 - val_loss: 0.2099
# Epoch 27/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8273 - loss: 0.5000
# Epoch 27: val_accuracy improved from 0.94444 to 0.94524, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.8273 - loss: 0.5000 - val_accuracy: 0.9452 - val_loss: 0.1954
# Epoch 28/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8236 - loss: 0.5084
# Epoch 28: val_accuracy improved from 0.94524 to 0.94722, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.8236 - loss: 0.5084 - val_accuracy: 0.9472 - val_loss: 0.1915
# Epoch 29/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8243 - loss: 0.5007
# Epoch 29: val_accuracy did not improve from 0.94722
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.8243 - loss: 0.5008 - val_accuracy: 0.9448 - val_loss: 0.1953
# Epoch 30/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8194 - loss: 0.5113
# Epoch 30: val_accuracy did not improve from 0.94722
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.8194 - loss: 0.5113 - val_accuracy: 0.9409 - val_loss: 0.1967
# Epoch 31/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8211 - loss: 0.4934
# Epoch 31: val_accuracy did not improve from 0.94722
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.8211 - loss: 0.4934 - val_accuracy: 0.9460 - val_loss: 0.1906
# Epoch 32/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8184 - loss: 0.5085
# Epoch 32: val_accuracy did not improve from 0.94722
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.8184 - loss: 0.5085 - val_accuracy: 0.9448 - val_loss: 0.1958
# Epoch 33/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8235 - loss: 0.5056
# Epoch 33: val_accuracy did not improve from 0.94722
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.8235 - loss: 0.5056 - val_accuracy: 0.9464 - val_loss: 0.1856
# Epoch 34/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8232 - loss: 0.4799
# Epoch 34: val_accuracy did not improve from 0.94722
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.8232 - loss: 0.4799 - val_accuracy: 0.9472 - val_loss: 0.1792
# Epoch 35/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8266 - loss: 0.4848
# Epoch 35: val_accuracy did not improve from 0.94722
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.8266 - loss: 0.4848 - val_accuracy: 0.9456 - val_loss: 0.1853
# Epoch 36/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8206 - loss: 0.5054
# Epoch 36: val_accuracy improved from 0.94722 to 0.94762, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.8206 - loss: 0.5053 - val_accuracy: 0.9476 - val_loss: 0.1851
# Epoch 37/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8273 - loss: 0.4871
# Epoch 37: val_accuracy did not improve from 0.94762
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.8273 - loss: 0.4871 - val_accuracy: 0.9452 - val_loss: 0.1809
# Epoch 38/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8351 - loss: 0.4775
# Epoch 38: val_accuracy improved from 0.94762 to 0.94921, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.8351 - loss: 0.4775 - val_accuracy: 0.9492 - val_loss: 0.1766
# Epoch 39/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8266 - loss: 0.4854
# Epoch 39: val_accuracy improved from 0.94921 to 0.95040, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.8266 - loss: 0.4854 - val_accuracy: 0.9504 - val_loss: 0.1790
# Epoch 40/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8409 - loss: 0.4697
# Epoch 40: val_accuracy did not improve from 0.95040
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.8409 - loss: 0.4697 - val_accuracy: 0.9437 - val_loss: 0.1834
# Epoch 41/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8351 - loss: 0.4633
# Epoch 41: val_accuracy did not improve from 0.95040
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.8351 - loss: 0.4633 - val_accuracy: 0.9456 - val_loss: 0.1773
# Epoch 42/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8289 - loss: 0.4818
# Epoch 42: val_accuracy did not improve from 0.95040
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.8289 - loss: 0.4818 - val_accuracy: 0.9504 - val_loss: 0.1734
# Epoch 43/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8296 - loss: 0.4807
# Epoch 43: val_accuracy improved from 0.95040 to 0.95238, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.8296 - loss: 0.4807 - val_accuracy: 0.9524 - val_loss: 0.1744
# Epoch 44/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8384 - loss: 0.4538
# Epoch 44: val_accuracy did not improve from 0.95238
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.8384 - loss: 0.4538 - val_accuracy: 0.9508 - val_loss: 0.1701
# Epoch 45/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8313 - loss: 0.4655
# Epoch 45: val_accuracy did not improve from 0.95238
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.8313 - loss: 0.4655 - val_accuracy: 0.9484 - val_loss: 0.1820
# Epoch 46/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8265 - loss: 0.4963
# Epoch 46: val_accuracy improved from 0.95238 to 0.95476, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 42s 82ms/step - accuracy: 0.8265 - loss: 0.4962 - val_accuracy: 0.9548 - val_loss: 0.1603
# Epoch 47/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8416 - loss: 0.4668
# Epoch 47: val_accuracy improved from 0.95476 to 0.95556, saving model to /kaggle/working/VGG19_best.h5
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 42s 83ms/step - accuracy: 0.8416 - loss: 0.4668 - val_accuracy: 0.9556 - val_loss: 0.1665
# Epoch 48/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8270 - loss: 0.4715
# Epoch 48: val_accuracy did not improve from 0.95556
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.8270 - loss: 0.4715 - val_accuracy: 0.9536 - val_loss: 0.1675
# Epoch 49/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8432 - loss: 0.4504
# Epoch 49: val_accuracy did not improve from 0.95556
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.8432 - loss: 0.4504 - val_accuracy: 0.9548 - val_loss: 0.1637
# Epoch 50/50
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8331 - loss: 0.4655
# Epoch 50: val_accuracy did not improve from 0.95556
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.8331 - loss: 0.4655 - val_accuracy: 0.9492 - val_loss: 0.1703
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 8s 87ms/step
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step

# %%
# Ensemble
val_stack = np.stack([val_preds[name] for name in models_dict.keys()], axis=-1)

def dirichlet_loss(weights):
    ensemble_pred = np.tensordot(val_stack, weights, axes=([2], [0]))
    return -np.mean(np.sum(to_categorical(y_val, 14) * np.log(ensemble_pred + 1e-8), axis=1))

init_weights = np.ones(len(models_dict)) / len(models_dict)
bounds = [(0, 1)] * len(models_dict)
constraints = [{'type': 'eq', 'fun': lambda w: 1 - sum(w)}]

res = minimize(dirichlet_loss, init_weights, bounds=bounds, constraints=constraints)
final_weights = res.x
print("Optimized Weights:", final_weights)

# Final Test Prediction
test_stack = np.stack([test_preds[name] for name in models_dict.keys()], axis=-1)
ensemble_test_pred = np.tensordot(test_stack, final_weights, axes=([2], [0]))
ensemble_test_labels = np.argmax(ensemble_test_pred, axis=1)

print("Ensemble Accuracy on Test Set:", accuracy_score(y_test, ensemble_test_labels))
# Out:
# Optimized Weights: [0.95019789 0.04980211]
# Ensemble Accuracy on Test Set: 0.9828571428571429

# %%
import numpy as np
from tensorflow.keras.models import load_model

class EnsembleModel:
    def __init__(self, model_paths, weights):
        self.models = [load_model(p) for p in model_paths]
        self.weights = np.array(weights)

    def predict(self, X):
        preds = [model.predict(X) for model in self.models]
        stacked = np.stack(preds, axis=-1)
        ensemble_pred = np.tensordot(stacked, self.weights, axes=([2], [0]))
        return ensemble_pred

    def predict_class(self, X):
        return np.argmax(self.predict(X), axis=1)
